# %% [markdown]
# # **Few-Shot Prompting**
#
# ### **Objective:**
# To perform few-shot prompting using LangChain and the OpenAI API by providing structured examples that guide the model’s responses for tasks such as classification, question answering, and creative content generation.
#
# ---
#
# ### **Note:**
# - Before running any demo, ensure that the **requirements.txt** file is installed. This file contains all the required dependencies for **all demos and guided practices under Building LLM Applications**.
#
# - If the dependencies were already installed earlier (after creating the virtual environment), there is no need to install them again. You can directly proceed with running the demo.
#
# - Refer to Lesson_01
# **Demo_01_Zero_Shot_Prompting.ipynb** Step 1
# for creating a virtual environment and installing the requirements.txt
#
# - Ensure you select the right kernel **Python (myenv)** while running the demos
#
#
# ---
#
# ### **Steps to perform:**
# 1. Set up the OpenAI API key
# 2. Define a function to get completion
# 3. Define your prompt
#
# ---

# %% [markdown]
# ### __Step 1: Set up the OpenAI API key__
#
# - Import the required libraries
# - The os library is used for interacting with the operating system, and openai is used to communicate with the OpenAI API.
# - Initialize the OpenAI client

# %%
import os
from openai import OpenAI

client = OpenAI()

# %% [markdown]
# ### __Step 2: Define a function to get completion__
#
# - Define the function to send a prompt to the OpenAI model and receive its completion
#
# This function uses client.chat.completions.create() to communicate with the API.
# The parameters include:
# - prompt: The text input for which the model generates a response
# - model: Specifies the OpenAI model used for generating completions (here, gpt-3.5-turbo)
# - temperature: Controls randomness in the output; a value of 0 makes responses deterministic

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )
    return response.choices[0].message.content

# %% [markdown]
# ### __Step 3: Define your prompts__
# - Create a few-shot prompt containing several examples that demonstrate how the model should classify customer feedback

# %%
prompt = """
Feedback: "I loved the quick service and friendly staff."
Classification: Great we are delighed to have a Positive sentiment
Score : 0.9

Feedback: "The product did not meet my expectations."
Classification: Oops, we are afraid its a Negative sentiment
Score : 0.2

Feedback: "I am not sure if this is the right product for me."
Classification: We will try to improve and satisfy you next time as its a Neutral sentiment.
Score : 0.5

Feedback: "Your customer support was helpful, very satisfied."
Classification:
Score:
"""
response = get_completion(prompt)
print(response)
# Out:
# Classification: Great, we are happy to hear that you had a positive experience with our customer support.
# Score: 0.8

# %% [markdown]
# - The above examples help the model infer how to classify new unseen feedback into positive, negative, or neutral sentiments.
#
# - You can also provide few-shot examples for question answering tasks

# %%
prompt = """

Q: What is the capital of Italy?
A: "Imperium Romanum in aeternum stabit.", Rome

Q: What is the capital of France?
A: "L'Empire romain devrait tenir pour l'éternité.", Paris

Q: What is the capital of Japan?
A: "日本は永遠に生き続けるべきです。", Tokyo

Q: What is the capital of Germany?
A: "Das Deutsche Reich sollte für immer bestehen.", Berlin

Q: What is the capital of Brazil?
A: "O Império Brasileiro deve durar para sempre.", Brasília

Q: What is the capital of USA?
A:

"""
response = get_completion(prompt)
print(response)
# Out:
# "The United States of America shall endure forever.", Washington D.C.

# %% [markdown]
# - You can further apply few-shot prompting for creative text generation, such as producing email subject lines

# %%
prompt = """
Task: Generate a subject line for the following emails.

Email: "Thank you for your purchase! Your order has been shipped and will arrive in 3-5 business days."
Subject: "Your Order Has been Shipped! Hurray"

Email: "We noticed you left items in your cart. Don’t miss out on these great deals!"
Subject: "Don’t Forget: Items Waiting in Your Cart!"

Email: "We’ve just launched a new product line. Check out our latest arrivals and get 10% off your first purchase."
Subject: "Explore Our New Arrivals & Enjoy 10% Off!"

Email: "Your subscription is about to expire. Renew now to continue enjoying our services."
Subject: 
"""
response = get_completion(prompt)
print(response)
# Out:
# "Renew Your Subscription Now and Keep Enjoying!"

# %% [markdown]
# In few-shot prompting, the model uses provided examples to understand the task context, style, and expected output. This technique is especially useful for tasks requiring interpretation or creativity, such as sentiment analysis, question answering, and email generation.

# %% [markdown]
# ### **Conclusion**
#
# By following these steps, you have successfully performed few-shot prompting using LangChain and the OpenAI API. This approach helps guide the model through structured examples, enabling it to learn contextual patterns and produce accurate, relevant responses for complex tasks.
#
# ---
